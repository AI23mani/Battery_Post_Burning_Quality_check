# %%
from ultralytics import YOLO

# Training parameters
INIT_LR = 1e-4
EPOCHS = 8
BS = 35

# Load the YOLO model
model = YOLO()

# Train the model
model.train(data="data.yaml", epochs=EPOCHS, batch=BS)
# Out:
# New https://pypi.org/project/ultralytics/8.2.48 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.34 🚀 Python-3.10.14 torch-2.3.1+cpu CPU (Intel Core(TM) i5-6300U 2.40GHz)
# ...

# %%
# !!yolo predict model="D:\AI COURSE TAMIL\First project\In-Line Post Training Data v1.v4i.yolov8-obb\runs\detect\train\weights/best.pt" source="D:\AI COURSE TAMIL\First project\In-Line Post Training Data v1.v4i.yolov8-obb\test_video"
# Out:
# ['Ultralytics YOLOv8.1.34 ðŸš€ Python-3.10.14 torch-2.3.1+cpu CPU (Intel Core(TM) i5-6300U 2.40GHz)',
#  'Model summary (fused): 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs',
#  '',
#  'video 1/2 (frame 1/1956) D:\\AI COURSE TAMIL\\First project\\In-Line Post Training Data v1.v4i.yolov8-obb\\test_video\\5622766-uhd_3840_2160_30fps.avi: 384x640 (no detections), 261.6ms',
#  'video 1/2 (frame 2/1956) D:\\AI COURSE TAMIL\\First project\\In-Line Post Training Data v1.v4i.yolov8-obb\\test_video\\5622766-uhd_3840_2160_30fps.avi: 384x640 (no detections), 211.3ms',
#  'video 1/2 (frame 3/1956) D:\\AI COURSE TAMIL\\First project\\In-Line Post Training Data v1.v4i.yolov8-obb\\test_video\\5622766-uhd_3840_2160_30fps.avi: 384x640 (no detections), 122.3ms',
#  'video 1/2 (frame 4/1956) D:\\AI COURSE TAMIL\\First project\\In-Line Post Training Data v1.v4i.yolov8-obb\\test_video\\5622766-uhd_3840_2160_30fps.avi: 384x640 (no detections), 151.7ms',
# ...

# %%
#prediction 
# !!yolo predict model="D:\AI COURSE TAMIL\First project\In-Line Post Training Data v1.v4i.yolov8-obb\runs\detect\train\weights/best.pt" source="D:\AI COURSE TAMIL\First project\In-Line Post Training Data v1.v4i.yolov8-obb\test_images"
# Out:
# ['Ultralytics YOLOv8.1.34 ðŸš€ Python-3.10.14 torch-2.3.1+cpu CPU (Intel Core(TM) i5-6300U 2.40GHz)',
#  'Model summary (fused): 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs',
#  '',
#  'image 1/6 D:\\AI COURSE TAMIL\\First project\\In-Line Post Training Data v1.v4i.yolov8-obb\\test_images\\987-3-_jpg.rf.29490111af61e975e64c764e4d24217a.jpg: 416x640 1 Bad Post, 1 Good Post, 275.5ms',
#  'image 2/6 D:\\AI COURSE TAMIL\\First project\\In-Line Post Training Data v1.v4i.yolov8-obb\\test_images\\IMG_20240124_104643_1_jpg.rf.1d3e82591c30bcea7fa4e17a207f7c72.jpg: 416x640 1 Bad Post, 1 Good Post, 250.7ms',
#  'image 3/6 D:\\AI COURSE TAMIL\\First project\\In-Line Post Training Data v1.v4i.yolov8-obb\\test_images\\IMG_20240124_105043_jpg.rf.2ce3a55bd8bba2c7e4f1c71ab18fc12d.jpg: 416x640 1 Bad Post, 1 Good Post, 220.0ms',
# ...

# %%
import cv2
import random
from ultralytics import YOLO

# Load the YOLO model
model = YOLO("D:\AI COURSE TAMIL\First project\In-Line Post Training Data v1.v4i.yolov8-obb\runs\detect\train2\weights/best.pt")

# Define a list of colors (one for each class)
colors = {}

# Open the webcam
cap = cv2.VideoCapture(0)

# Create a named window and set it to full screen
cv2.namedWindow("Webcam", cv2.WND_PROP_FULLSCREEN)
cv2.setWindowProperty("Webcam", cv2.WND_PROP_FULLSCREEN, cv2.WINDOW_FULLSCREEN)

while True:
    ret, frame = cap.read()
    if not ret:
        break

    # Perform prediction
    results = model(frame)

    # Process the results
    for result in results:
        boxes = result.boxes
        for box in boxes:
            x1, y1, x2, y2 = map(int, box.xyxy[0])
            conf = box.conf[0]
            cls = int(box.cls[0])

            # Assign a color to the class if not already assigned
            if cls not in colors:
                colors[cls] = [random.randint(0, 255) for _ in range(3)]

            # Get the color for the current class
            color = colors[cls]

            # Draw rectangle
            cv2.rectangle(frame, (x1, y1), (x2, y2), color, 2)

            # Put label
            label = f'{model.names[cls]} {conf:.2f}'
            cv2.putText(frame, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, color, 2)

    # Display the frame
    cv2.imshow("Webcam", frame)

    # Break the loop on 'q' key press
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the capture and close the windows
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 Laptop Battery, 283.1ms
# Speed: 6.5ms preprocess, 283.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 302.4ms
# Speed: 0.0ms preprocess, 302.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Laptop Battery, 294.1ms
# Speed: 4.5ms preprocess, 294.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Laptop Battery, 221.5ms
# Speed: 0.0ms preprocess, 221.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Laptop Battery, 221.2ms
# Speed: 0.0ms preprocess, 221.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 221.6ms
# Speed: 0.0ms preprocess, 221.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 229.9ms
# Speed: 0.0ms preprocess, 229.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# ...
